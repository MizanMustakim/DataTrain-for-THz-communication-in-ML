# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('coefficient2.xlsx')

# %%
n = []
DISTANCE = []
def path_loss():
    global n
    global DISTANCE
    
    ask = input('Do you want to clear the storage list (y/n): ')
    
    if ask.lower() == 'y':
        n.clear()
        print('List has been cleared!')
        
        ask1 = input('Do you want add new value? (y/n): ')
        if ask1.lower() == 'y':
            ask2 = float(input("Enter the number of amount of node: "))
            ask3 = input("Does it have any diagonal distance? (y/n): ")
            if ask3.lower() == 'y':
                ask4 = float(input("Enter the diagonal length: "))
                ask5 = float(input("How many diagonal length do you have: "))
                DISTANCE = (float(ask2 - 1) * 0.8 + (ask4 * ask5))
                print('----------------------------------------------')
                print("----------------- Distance = -----------------",DISTANCE)
            elif ask3.lower() == 'n':
                DISTANCE = float(float(ask2 - 1) * 0.8)
                print('----------------------------------------------')
                print("----------------- Distance = {}-----------------".format(DISTANCE))
                
        for i in range(1, 11):
            fq = np.array(df.loc[i, ('Unnamed: 0')])
            rI = np.array(df.loc[i, ('blood')])
            aC = np.array(df.loc[i, ('blood.1')])
            p_spreading = ((4*np.pi*(fq*10**12) * rI * (DISTANCE * 10**-3)) / (3 * 10**8)) ** 2
            p_abs = np.exp((aC * 10**3) * (DISTANCE * 10**(-3)))
            pa_LO1 = p_spreading * p_abs
            f = 20 * np.log10(pa_LO1)
            i += 1
            n.append(f)
        
        
    elif ask.lower() == 'n':
        print(n)
            
    else:
        print("Please type y or n. No other Commands are allowed.")
        
#d1 = 9 * .8       ### route 1-2-3-6-9-12-15-18-21-24
path_loss()
# Out:
# Do you want to clear the storage list (y/n): y
# List has been cleared!
# Do you want add new value? (y/n): y
# Enter the number of amount of node: 10
# Does it have any diagonal distance? (y/n): n
# ----------------------------------------------
# ----------------- Distance = 7.2-----------------

# %%
freq = np.array(df.loc[1:, ('Unnamed: 0')])
blood_rI = np.array(df.loc[1:, ('blood')])
blood_aC = np.array(df.loc[1:, ('blood.1')])
blood_paLO = np.array(df.loc[1:, ('Unnamed: 15')])
data = {'Frequency': freq,
        'Blood (Refractive index)': blood_rI,
        'Blood (absorption coefficient)': blood_aC,
        "Path Loss (dB) d=1mm": blood_paLO,
        'Path Loss(dB) node = 10': n}
df1 = pd.DataFrame(data)
df1
# Out:
#   Frequency Blood (Refractive index) Blood (absorption coefficient)  \
# 0       0.2                   2.7108                        11.7758
# 1       0.4                   2.2105                        16.0218
# 2       0.6                   2.0427                        18.6761
# 3       0.8                   1.9573                        20.9721
# 4         1                   1.9013                        23.1726
# 5       1.2                   1.8588                        25.3088
# 6       1.4                   1.8239                        27.3544
# 7       1.6                    1.794                        29.2782
# 8       1.8                   1.7681                        31.0583
# 9         2                   1.7454                        32.6847
#
#   Path Loss (dB) d=1mm  Path Loss(dB) node = 10
# 0              156.532               824.981697
# 1              201.909              1099.016688
# 2              230.636              1270.684591
# 3              254.835              1418.528431
# 4               277.32              1559.516323
# 5               298.65              1695.885395
# 6              318.766              1826.162563
# 7              337.508              1948.506482
# 8              354.764              2061.624574
# 9              370.496              2164.942862

# %%
path_loss()
df1['Path Loss(dB) node = 9'] = n
df1
df1.to_csv('update_1.csv')
# Out:
# Do you want to clear the storage list (y/n): y
# List has been cleared!
# Do you want add new value? (y/n): y
# Enter the number of amount of node: 9
# Does it have any diagonal distance? (y/n): y
# Enter the diagonal length: 1.13
# How many diagonal length do you have: 1
# ----------------------------------------------
# ----------------- Distance = ----------------- 7.53

# %%
df1
# Out:
#   Frequency Blood (Refractive index) Blood (absorption coefficient)  \
# 0       0.2                   2.7108                        11.7758
# 1       0.4                   2.2105                        16.0218
# 2       0.6                   2.0427                        18.6761
# 3       0.8                   1.9573                        20.9721
# 4         1                   1.9013                        23.1726
# 5       1.2                   1.8588                        25.3088
# 6       1.4                   1.8239                        27.3544
# 7       1.6                    1.794                        29.2782
# 8       1.8                   1.7681                        31.0583
# 9         2                   1.7454                        32.6847
#
#   Path Loss (dB) d=1mm  Path Loss(dB) node = 10  Path Loss(dB) node = 9
# 0              156.532               824.981697              859.513685
# 1              201.909              1099.016688             1145.719171
# 2              230.636              1270.684591             1324.995209
# 3              254.835              1418.528431             1479.420175
# 4               277.32              1559.516323             1626.715455
# 5               298.65              1695.885395             1769.207611
# 6              318.766              1826.162563             1905.348171
# 7              337.508              1948.506482             2033.206362
# 8              354.764              2061.624574             2151.426832
# 9              370.496              2164.942862             2259.406941
